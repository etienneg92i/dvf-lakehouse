-- %%
CREATE CATALOG IF NOT EXISTS immo;  -- si la création échoue, utilise le catalogue "workspace" existant
USE CATALOG immo;

CREATE SCHEMA IF NOT EXISTS landing;
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

CREATE VOLUME IF NOT EXISTS landing.dvf_raw;
