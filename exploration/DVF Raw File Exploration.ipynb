# %%
display(dbutils.fs.ls("/Volumes/immo/landing/dvf_raw/"))

# Aperçu des premières lignes brutes
print(dbutils.fs.head("/Volumes/immo/landing/dvf_raw/ValeursFoncieres-2025.txt", 2000))

# %%
# %sql
SELECT COUNT(*) FROM immo.bronze.dvf_mutations;
